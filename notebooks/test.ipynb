# %%
import graph_tool.all as gt

g = gt.collection.ns["us_roads/DC"]

# %%
state = gt.minimize_blockmodel_dl(g)

# %%
state.draw()
# Out:
# <VertexPropertyMap object with value type 'vector<double>', for Graph 0x7f036c86df90, at 0x7f036a770190>

# %%
state = gt.minimize_nested_blockmodel_dl(g)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /workspaces/codespaces-jupyter/notebooks/test.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell://codespaces%2Bupgraded-orbit-9xx67vxvp4j3gw5/workspaces/codespaces-jupyter/notebooks/test.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> state = gt.minimize_nested_blockmodel_dl(g)
#
# NameError: name 'gt' is not defined
